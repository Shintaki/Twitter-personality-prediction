# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import re
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import stopwords 
from nltk import word_tokenize
from keras.models import Model
from keras.layers import Dense, Input, Dropout, LSTM, Activation,concatenate,Bidirectional,BatchNormalization, Lambda, Layer
from keras.initializers import Constant
import keras.backend as K
from keras.layers.embeddings import Embedding
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
import emoji
# Out:
# Using TensorFlow backend.

# %%
print(tf.__version__)
print(tf.test.gpu_device_name())
# Out:
# 2.1.0
# /device:GPU:0

# %%
RANDOM_SEED = 42

np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# %%
data = pd.read_csv("./dataset/dataset.csv")
print(data.head())
# Out:
#    type                                              posts
# 0  INFJ  'http://www.youtube.com/watch?v=qsXHcwe3krw|||...
# 1  ENTP  'I'm finding the lack of me in these posts ver...
# 2  INTP  'Good one  _____   https://www.youtube.com/wat...
# 3  INTJ  'Dear INTP,   I enjoyed our conversation the o...
# 4  ENTJ  'You're fired.|||That's another silly misconce...

# %%
def char_is_emoji(character):
    return character in emoji.UNICODE_EMOJI

def text_has_emoji(text):
    return(bool(emoji.get_emoji_regexp().search(text)))

def returnEmojis(text):
    listEmojis=[]
    for c in text:
        if (char_is_emoji(c)):
            listEmojis.append(c)
    return(listEmojis)

# %%
# Add features to DataFrame
'''data['words_per_comment'] = data['posts'].apply(lambda x: len(x.split())/50)
data['question_per_comment'] = data['posts'].apply(lambda x: x.count('?')/50)
data['excl_per_comment'] = data['posts'].apply(lambda x: x.count('!')/50)
data['ellipsis_per_comment'] = data['posts'].apply(lambda x: x.count('...')/50)
#data['@_per_comment'] = data['posts'].apply(lambda x: x.count('@')/50)
#data['#_per_comment'] = data['posts'].apply(lambda x: x.count('#')/50)
data['emojis_per_comment'] = data['posts'].apply(lambda x: (len(returnEmojis(x)))/50)
print(data.head())
data.shape'''
# Out:
# "data['words_per_comment'] = data['posts'].apply(lambda x: len(x.split())/50)\ndata['question_per_comment'] = data['posts'].apply(lambda x: x.count('?')/50)\ndata['excl_per_comment'] = data['posts'].apply(lambda x: x.count('!')/50)\ndata['ellipsis_per_comment'] = data['posts'].apply(lambda x: x.count('...')/50)\n#data['@_per_comment'] = data['posts'].apply(lambda x: x.count('@')/50)\n#data['#_per_comment'] = data['posts'].apply(lambda x: x.count('#')/50)\ndata['emojis_per_comment'] = data['posts'].apply(lambda x: (len(returnEmojis(x)))/50)\nprint(data.head())\ndata.shape"

# %%
full_Pers_list = {'INFP' :0 ,'INTJ' :1 ,'INFJ' :2, 'INTP' :3 ,'ENFP' :4 ,'ENTJ' :5, 'ENTP' :6 ,'ENFJ' :7, 'ISFJ' :8 ,'ISFP' :9 ,'ISTJ' :10 ,'ISTP' :11 ,'ESFJ' :12,'ESFP' :13 ,'ESTJ' :14 ,'ESTP' :15}
def type_to_16(typeList):
    labels=[]
    for t in typeList:
        labels.append(full_Pers_list[t])
    return(labels)

def type16_to_vector_label(data):
    for i,label in enumerate(data):
        translation=np.zeros((16))
        translation[int(label)]=1
        data[i]=translation
        
labels=type_to_16(data["type"])
data["labels"]=labels
data.tail()
# Out:
#       type                                              posts  labels
# 8670  ISFP  'https://www.youtube.com/watch?v=t8edHB_h908||...       9
# 8671  ENFP  'So...if this thread already exists someplace ...       4
# 8672  INTP  'So many questions when i do these things.  I ...       3
# 8673  INFP  'I am very conflicted right now when it comes ...       0
# 8674  INFP  'It has been too long since I have been on per...       0

# %%
b_Pers = {'I':0, 'E':1, 'N':0, 'S':1, 'F':0, 'T':1, 'J':0, 'P':1}
b_Pers_list = [{0:'I', 1:'E'}, {0:'N', 1:'S'}, {0:'F', 1:'T'}, {0:'J', 1:'P'}]

def translate_personality(personality):
    # transform mbti to binary vector
    
    return [b_Pers[l] for l in personality]

# %%
# We want to remove these from the posts
unique_type_list = ['INFJ', 'ENTP', 'INTP', 'INTJ', 'ENTJ', 'ENFJ', 'INFP', 'ENFP',
       'ISFP', 'ISTP', 'ISFJ', 'ISTJ', 'ESTP', 'ESFP', 'ESTJ', 'ESFJ']
  
unique_type_list = [x.lower() for x in unique_type_list]


# Lemmatize
stemmer = PorterStemmer()
lemmatiser = WordNetLemmatizer()

# Cache the stop words for speed 
cachedStopWords = stopwords.words("english")

def pre_process_data(data, remove_stop_words=True, remove_mbti_profiles=True):

    list_personality = []
    list_posts = []
    len_data = len(data)
    i=0
    
    for row in data.iterrows():
        i+=1
        if (i % 500 == 0 or i == 1 or i == len_data):
            print("%s of %s rows" % (i, len_data))

        ##### Remove and clean comments using regular expressions
        posts = row[1].posts
        temp = re.sub('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', ' ', posts)
        temp = re.sub("[^a-zA-Z]", " ", temp)
        temp = re.sub(' +', ' ', temp).lower()
        if remove_stop_words:
            temp = " ".join([lemmatiser.lemmatize(w) for w in temp.split(' ') if w not in cachedStopWords])
        else:
            temp = " ".join([lemmatiser.lemmatize(w) for w in temp.split(' ')])
            
        if remove_mbti_profiles:
            for t in unique_type_list:
                temp = temp.replace(t,"")
        ##### Remove single-charactered words that remain from the cleaning
        words=temp.split()
        finalTemp=""
        for word in words:
            if(len(word)>1):
                finalTemp=finalTemp+" "+word
        type_labelized = translate_personality(row[1].type)
        list_personality.append(type_labelized)
        list_posts.append(finalTemp)

    list_posts = np.array(list_posts)
    list_personality = np.array(list_personality)
    return list_posts, list_personality

# %%
list_posts, list_personality  = pre_process_data(data, remove_stop_words=True)
# Out:
# 1 of 8675 rows
# 500 of 8675 rows
# 1000 of 8675 rows
# 1500 of 8675 rows
# 2000 of 8675 rows
# 2500 of 8675 rows
# 3000 of 8675 rows
# 3500 of 8675 rows
# 4000 of 8675 rows
# 4500 of 8675 rows
# 5000 of 8675 rows
# 5500 of 8675 rows
# 6000 of 8675 rows
# 6500 of 8675 rows
# 7000 of 8675 rows
# 7500 of 8675 rows
# 8000 of 8675 rows
# 8500 of 8675 rows
# 8675 of 8675 rows

# %%
print(list_posts[1])
print(list_personality[1])
print(data["labels"][1])
# Out:
#  finding lack post alarming sex boring position often example girlfriend currently environment creatively use cowgirl missionary enough giving new meaning game theory hello grin take converse flirting acknowledge presence return word smooth wordplay cheeky grin lack balance hand eye coordination real iq test score internet iq test funny score higher like former response thread mention believe iq test banish know vanish site year half return find people still commenting post liking idea thought know think thing sometimes go old sherlock holmes quote perhaps man special knowledge special power like rather encourages seek complex cheshirewolf tumblr com post really never thought real function judge use use ne ti dominates fe emotion rarely si also use ni due strength know though ingenious saying really want try see happens playing first person shooter back drive around want see look rock paper one best make lol guy lucky really high tumblr system hear new first person shooter game rocking hell soundtrack auto sound equipment shake heaven managed put couple way connected thing ne ne dominates aware environment se dominates example shawn spencer patrick jane well charlie first admit get jealous like chalk heart mixed dominate like noticed like known upload clip mic away mouth hear anything ninja assassin style splatter tik tok really great song long mental block singer love beat make bounce drop io swck mic really close mouth smokin ace assassin ball playing background sociable extrovert extrovert sociable sherlock movie normally played extj book said movie looked good except called sherlock holmes oh never fear kissing guy kiss animal nothing vanish personal taste liking guy kissed know one sound pretty much like area going right trying figure way want take life want many thing biggest problem know operating impression female never looked boxy okay help gay friend time one developed little crush get red described living worst nightmare trapped one place one one around dull wood serial killer would perfect place sadly tbh biased sound like shadowed think maybe hurt turned tell typical trait left check list sorry seems came bad time already reached quota however female like female make deal kick one antp leaning toward easy identify also imagine interrogation would go little bit like jack except mechanical rigging shock treatment equipment abandoned building old car batty jumper compliment trust psychopathic except emoticon weird one like laughing get hurt people running lawn mower like theme live know heart usual leave thing end mean time time work thing work mine mbp pleasure meet damn need trust instinct would closer going say exfp leaning toward way responded friend even gay lesbian one always come advice bow master great able build building duck duck duck shotgun never hard sad losing someone like knew right give big pat back awesome always correct oh tell stupid know play make laugh going take neuropsychology psychologist nightowl wake pm stay awake till personal opinion backed theory would suggest socially difficult socially indifferent also use social situation need arises personal stock desktop downloaded random stock site stock photobuckets tell open photoshop glad like static thanks made friend several hour work constructed every line static get avatar later one fellow teammate psychologist keep around long enough diagnosis like toy diagnosis psychologist friend friend tell
# [1 0 1 1]
# 6

# %%
#returns the max word numbers 
def max_post_words(posts):
    maxLen=0
    averageLen=0
    for post in posts:
        words=post.split()
        averageLen=averageLen+len(words)
        if maxLen < len(words):
            maxLen=len(words)
    averageLen=int(averageLen/len(posts))
    return maxLen,averageLen
print(list_posts.shape)
print(list_personality.shape)
maxlength,averagelen=max_post_words(list_posts)
print(maxlength)
print(averagelen)
# Out:
# (8675,)
# (8675, 4)
# 883
# 585

# %%
def read_glove_vecs(glove_file):
    with open(glove_file, 'r', encoding="utf8") as f:
        words = set()
        word_to_vec_map = {}
        for line in f:
            line = line.strip().split()
            curr_word = line[0]
            words.add(curr_word)
            word_to_vec_map[curr_word] = np.array(line[1:], dtype=np.float64)
        
        i = 1
        words_to_index = {}
        index_to_words = {}
        for w in sorted(words):
            words_to_index[w] = i
            index_to_words[i] = w
            i = i + 1
    return words_to_index, index_to_words, word_to_vec_map
word_to_index, index_to_word, word_to_vec_map = read_glove_vecs('./dataset/glove.6B/glove.6B.50d.txt')

# %%
print(word_to_index["finding"])
print(index_to_word[148433])
print(word_to_vec_map["finding"])
# Out:
# 148433
# finding
# [ 1.0427    -0.0063726  0.14249   -0.20253    0.81903    0.45835
#  -0.53618    0.4273     0.87353    0.36      -0.13102    0.031936
#  -0.3458     0.048457   0.53903    0.076773   0.51641   -0.39471
#   0.33282   -0.71322   -0.014848   0.5072     0.1407     0.052006
#   0.47805   -1.2841    -0.50835    0.040056   0.55624   -0.14598
#   2.6381    -0.19551   -0.22558   -1.0202     0.57369    0.20545
#  -0.14149    0.44701    0.17831   -0.55761   -0.14858   -0.14687
#   0.29202    0.35834    0.22295   -0.12368    0.12302    0.53954
#   0.29452   -0.051312 ]

# %%
def sentences_to_indices(X, word_to_index, max_len):
    m = X.shape[0]                                   
    X_indices = np.zeros((m,max_len))
    for i in range(m):
        if (i % 500 == 0 or i == 1 or i == m):
            print("%s of %s rows" % (i, m))
        sentence_words =X[i].lower().split()
        j = 0
        for w in sentence_words:
            if j==max_len:
                break
            if w in word_to_index:
                X_indices[i, j] = word_to_index[w]
            j = j+1
    return X_indices
X=sentences_to_indices(list_posts, word_to_index, averagelen)
print(X.shape)
# Out:
# 0 of 8675 rows
# 1 of 8675 rows
# 500 of 8675 rows
# 1000 of 8675 rows
# 1500 of 8675 rows
# 2000 of 8675 rows
# 2500 of 8675 rows
# 3000 of 8675 rows
# 3500 of 8675 rows
# 4000 of 8675 rows
# 4500 of 8675 rows
# 5000 of 8675 rows
# 5500 of 8675 rows
# 6000 of 8675 rows
# 6500 of 8675 rows
# 7000 of 8675 rows
# 7500 of 8675 rows
# 8000 of 8675 rows
# 8500 of 8675 rows
# (8675, 585)

# %%
# Add Features to Inputs
'''X=np.ndarray.tolist(X)
waste=[post.append(data['words_per_comment'][i]) for i,post in enumerate(X)]
waste=[post.append(data['question_per_comment'][i]) for i,post in enumerate(X)]
waste=[post.append(data['excl_per_comment'][i]) for i,post in enumerate(X)]
waste=[post.append(data['ellipsis_per_comment'][i]) for i,post in enumerate(X)]
#waste=[post.append(data['@_per_comment'][i]) for i,post in enumerate(X)]
#waste=[post.append(data['#_per_comment'][i]) for i,post in enumerate(X)]
waste=[post.append(data['emojis_per_comment'][i]) for i,post in enumerate(X)]
print(X[0])
X=np.array(X)
print(X[0])'''
# Out:
# "X=np.ndarray.tolist(X)\nwaste=[post.append(data['words_per_comment'][i]) for i,post in enumerate(X)]\nwaste=[post.append(data['question_per_comment'][i]) for i,post in enumerate(X)]\nwaste=[post.append(data['excl_per_comment'][i]) for i,post in enumerate(X)]\nwaste=[post.append(data['ellipsis_per_comment'][i]) for i,post in enumerate(X)]\n#waste=[post.append(data['@_per_comment'][i]) for i,post in enumerate(X)]\n#waste=[post.append(data['#_per_comment'][i]) for i,post in enumerate(X)]\nwaste=[post.append(data['emojis_per_comment'][i]) for i,post in enumerate(X)]\nprint(X[0])\nX=np.array(X)\nprint(X[0])"

# %%
def pretrained_embedding_layer(word_to_vec_map, word_to_index):
    vocab_len = len(word_to_index) + 1
    emb_dim = word_to_vec_map["cucumber"].shape[0] 
    
    emb_matrix = np.zeros((vocab_len,emb_dim))
    for word, idx in word_to_index.items():
        emb_matrix[idx, :] = word_to_vec_map[word]
    embedding_layer = Embedding(vocab_len,emb_dim) 
    embedding_layer.build((None,)) 
    embedding_layer.set_weights([emb_matrix])
    
    return embedding_layer

# %%
def f1(y_true, y_pred):
    def recall(y_true, y_pred):
        """Recall metric.

        Only computes a batch-wise average of recall.

        Computes the recall, a metric for multi-label classification of
        how many relevant items are selected.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision(y_true, y_pred):
        """Precision metric.

        Only computes a batch-wise average of precision.

        Computes the precision, a metric for multi-label classification of
        how many selected items are relevant.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
def personnality_model(input_shape, word_to_vec_map, word_to_index):
    
    sentence_indices = Input(shape=input_shape, dtype='int32')
    embedding_layer = pretrained_embedding_layer(word_to_vec_map, word_to_index)
    embeddings = embedding_layer(sentence_indices)   
    X = Bidirectional(LSTM(128,return_sequences=False))(embeddings)
    X = Dropout(0.25)(X)
    X1=Dense(1,name="I/E_classifier")(X)
    X1Output=Activation("sigmoid")(X1)
    '''
    X2=Dense(1,name="N/S_classifier")(X)
    X2Output=Activation("sigmoid")(X2)
    
    X3=Dense(1,name="F/T_classifier")(X)
    X3Output=Activation("sigmoid")(X3)
    
    X4=Dense(1,name="J/P_classifier")(X)
    X4Output=Activation("sigmoid")(X4)'''
    model = model = Model(inputs=sentence_indices, outputs=X1Output)
    return model
model = personnality_model((averagelen,), word_to_vec_map, word_to_index)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 585)               0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 585, 50)           20000050
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 256)               183296
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# I/E_classifier (Dense)       (None, 1)                 257
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 20,183,603
# Trainable params: 20,183,603
# Non-trainable params: 0
# _________________________________________________________________

# %%
"0 for I/E Classification"
Y = list_personality[:,0]
print(Y[0])
# Out:
# 0

# %%
# initializing some hyperparameters
INIT_LR = 0.001
EPOCHS = 10
BS = 32
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)
model.compile(loss="binary_crossentropy", optimizer=opt, metrics=['accuracy',f1])
(X_train, X_temp, Y_train, Y_temp) = train_test_split(X,Y,test_size=0.2, random_state=42)
(X_valid, X_test, Y_valid, Y_test) = train_test_split(X_temp,Y_temp,test_size=0.5, random_state=42)
history=model.fit(X_train, Y_train,validation_data=(X_valid,Y_valid), batch_size=BS , epochs = EPOCHS, shuffle=True)
# Out:
# Train on 6940 samples, validate on 867 samples
# Epoch 1/10
# 6940/6940 [==============================] - 167s 24ms/step - loss: 0.5504 - accuracy: 0.7666 - f1: 5.7604e-04 - val_loss: 0.5098 - val_accuracy: 0.7924 - val_f1: 0.0000e+00
# Epoch 2/10
# 6940/6940 [==============================] - 162s 23ms/step - loss: 0.5364 - accuracy: 0.7670 - f1: 0.0026 - val_loss: 0.5171 - val_accuracy: 0.7924 - val_f1: 0.0000e+00
# Epoch 3/10
# 6940/6940 [==============================] - 164s 24ms/step - loss: 0.5109 - accuracy: 0.7702 - f1: 0.0549 - val_loss: 0.5345 - val_accuracy: 0.7912 - val_f1: 0.0143
# Epoch 4/10
# 6940/6940 [==============================] - 168s 24ms/step - loss: 0.4294 - accuracy: 0.8045 - f1: 0.3445 - val_loss: 0.6840 - val_accuracy: 0.6401 - val_f1: 0.2211
# Epoch 5/10
# 6940/6940 [==============================] - 163s 23ms/step - loss: 0.3041 - accuracy: 0.8686 - f1: 0.6545 - val_loss: 0.7306 - val_accuracy: 0.7266 - val_f1: 0.1554
# Epoch 6/10
# 6940/6940 [==============================] - 169s 24ms/step - loss: 0.1743 - accuracy: 0.9333 - f1: 0.8426 - val_loss: 0.9406 - val_accuracy: 0.6563 - val_f1: 0.2038
# Epoch 7/10
# 6940/6940 [==============================] - 172s 25ms/step - loss: 0.0846 - accuracy: 0.9713 - f1: 0.9334 - val_loss: 1.1655 - val_accuracy: 0.6309 - val_f1: 0.2215
# Epoch 8/10
# 6940/6940 [==============================] - 171s 25ms/step - loss: 0.0344 - accuracy: 0.9911 - f1: 0.9790 - val_loss: 1.5302 - val_accuracy: 0.6574 - val_f1: 0.2150
# Epoch 9/10
# 6940/6940 [==============================] - 170s 24ms/step - loss: 0.0214 - accuracy: 0.9939 - f1: 0.9867 - val_loss: 1.6139 - val_accuracy: 0.6770 - val_f1: 0.1627
# Epoch 10/10
# 6940/6940 [==============================] - 165s 24ms/step - loss: 0.0079 - accuracy: 0.9987 - f1: 0.9967 - val_loss: 1.7799 - val_accuracy: 0.6597 - val_f1: 0.1698

# %%
test_loss, test_acc,test_f1 = model.evaluate(X_test,Y_test)
print("Accuracy : ",test_acc)
print("F1 Score :",test_f1)
print("Loss :",test_loss)
Yhat=model.predict(X_test)
correct=0
for i,prediction in enumerate(Yhat):
    print("Prediction :",prediction," Actual Value :",Y_test[i] )
# Out:
# 868/868 [==============================] - 3s 4ms/step
# Accuracy :  0.6877880096435547
# F1 Score : 0.2729169428348541
# Loss : 1.7425766522708577
# Prediction : [0.00023619]  Actual Value : 0
# Prediction : [0.1644935]  Actual Value : 0
# Prediction : [0.00178077]  Actual Value : 0
# Prediction : [4.0337902e-08]  Actual Value : 0
# Prediction : [9.980277e-06]  Actual Value : 1
# Prediction : [0.01073133]  Actual Value : 0
# Prediction : [0.00512266]  Actual Value : 0
# Prediction : [0.03530119]  Actual Value : 0
# Prediction : [0.99995935]  Actual Value : 0
# Prediction : [0.00145185]  Actual Value : 0
# Prediction : [0.00393875]  Actual Value : 0
# Prediction : [0.999772]  Actual Value : 0
# Prediction : [1.4592298e-05]  Actual Value : 1
# Prediction : [0.00190533]  Actual Value : 0
# Prediction : [0.06252081]  Actual Value : 1
# Prediction : [3.496225e-05]  Actual Value : 1
# Prediction : [0.22972]  Actual Value : 1
# Prediction : [0.2181403]  Actual Value : 0
# Prediction : [4.3635787e-06]  Actual Value : 0
# Prediction : [0.00034822]  Actual Value : 0
# Prediction : [3.974029e-05]  Actual Value : 0
# Prediction : [0.67987317]  Actual Value : 1
# Prediction : [0.09049374]  Actual Value : 0
# Prediction : [7.696608e-06]  Actual Value : 1
# Prediction : [1.5017515e-05]  Actual Value : 0
# Prediction : [0.00123342]  Actual Value : 0
# Prediction : [0.59619105]  Actual Value : 1
# Prediction : [0.00018992]  Actual Value : 1
# Prediction : [0.5902152]  Actual Value : 1
# Prediction : [9.2592626e-07]  Actual Value : 0
# Prediction : [0.03224895]  Actual Value : 0
# Prediction : [0.00291746]  Actual Value : 0
# Prediction : [0.07270221]  Actual Value : 0
# Prediction : [0.7526444]  Actual Value : 0
# Prediction : [0.98260605]  Actual Value : 0
# Prediction : [0.10922161]  Actual Value : 0
# Prediction : [7.690053e-09]  Actual Value : 0
# Prediction : [0.04251821]  Actual Value : 0
# Prediction : [0.14507987]  Actual Value : 1
# Prediction : [0.0010017]  Actual Value : 0
# Prediction : [0.00340408]  Actual Value : 1
# Prediction : [0.00914711]  Actual Value : 1
# Prediction : [0.00014947]  Actual Value : 0
# Prediction : [9.111355e-06]  Actual Value : 0
# Prediction : [0.9973852]  Actual Value : 0
# Prediction : [0.00528962]  Actual Value : 0
# Prediction : [2.8086695e-06]  Actual Value : 0
# Prediction : [0.02384538]  Actual Value : 0
# Prediction : [1.7371209e-05]  Actual Value : 0
# Prediction : [0.6109538]  Actual Value : 0
# Prediction : [0.00048444]  Actual Value : 0
# Prediction : [0.23083907]  Actual Value : 0
# Prediction : [6.4824904e-05]  Actual Value : 0
# Prediction : [3.9134757e-05]  Actual Value : 0
# Prediction : [0.00233013]  Actual Value : 0
# Prediction : [0.5846828]  Actual Value : 0
# Prediction : [0.00017826]  Actual Value : 0
# Prediction : [0.71281034]  Actual Value : 0
# Prediction : [0.85320973]  Actual Value : 0
# Prediction : [3.4412007e-08]  Actual Value : 0
# Prediction : [0.00796621]  Actual Value : 0
# Prediction : [0.9792706]  Actual Value : 1
# Prediction : [0.00338416]  Actual Value : 1
# Prediction : [0.00019316]  Actual Value : 0
# Prediction : [0.1750051]  Actual Value : 0
# Prediction : [0.0457761]  Actual Value : 1
# Prediction : [0.00942668]  Actual Value : 0
# Prediction : [0.999671]  Actual Value : 1
# Prediction : [0.0178054]  Actual Value : 0
# Prediction : [8.7017295e-05]  Actual Value : 1
# Prediction : [0.000457]  Actual Value : 0
# Prediction : [0.00022882]  Actual Value : 0
# Prediction : [0.05631852]  Actual Value : 0
# Prediction : [0.83448786]  Actual Value : 0
# Prediction : [0.01332074]  Actual Value : 0
# Prediction : [0.7717141]  Actual Value : 0
# Prediction : [0.00048235]  Actual Value : 0
# Prediction : [0.9967829]  Actual Value : 0
# Prediction : [0.9986028]  Actual Value : 0
# Prediction : [0.9736264]  Actual Value : 0
# Prediction : [7.0259295e-05]  Actual Value : 0
# Prediction : [0.9999722]  Actual Value : 0
# Prediction : [2.7156024e-05]  Actual Value : 0
# Prediction : [0.99967074]  Actual Value : 0
# Prediction : [2.8124812e-06]  Actual Value : 1
# Prediction : [0.00466794]  Actual Value : 0
# Prediction : [2.6295384e-06]  Actual Value : 0
# Prediction : [0.00041735]  Actual Value : 0
# Prediction : [0.03114947]  Actual Value : 0
# Prediction : [0.00015145]  Actual Value : 0
# Prediction : [0.35692182]  Actual Value : 1
# Prediction : [0.16238263]  Actual Value : 1
# Prediction : [0.0038526]  Actual Value : 0
# Prediction : [0.03783622]  Actual Value : 0
# Prediction : [0.00230577]  Actual Value : 0
# Prediction : [0.00030496]  Actual Value : 0
# Prediction : [9.499423e-06]  Actual Value : 1
# Prediction : [0.7788291]  Actual Value : 1
# Prediction : [0.00649117]  Actual Value : 1
# Prediction : [9.7823366e-05]  Actual Value : 0
# Prediction : [7.3557867e-06]  Actual Value : 0
# Prediction : [6.135712e-05]  Actual Value : 0
# Prediction : [0.0001209]  Actual Value : 0
# Prediction : [0.9993343]  Actual Value : 1
# Prediction : [0.82804334]  Actual Value : 0
# Prediction : [0.13074091]  Actual Value : 0
# Prediction : [2.0744992e-06]  Actual Value : 0
# Prediction : [0.00729579]  Actual Value : 1
# Prediction : [8.991656e-06]  Actual Value : 0
# Prediction : [7.153502e-06]  Actual Value : 1
# Prediction : [0.01919462]  Actual Value : 0
# Prediction : [3.6862486e-06]  Actual Value : 0
# Prediction : [1.24133185e-05]  Actual Value : 0
# Prediction : [5.290337e-05]  Actual Value : 0
# Prediction : [0.00213491]  Actual Value : 0
# Prediction : [0.00058221]  Actual Value : 0
# Prediction : [0.00230448]  Actual Value : 0
# Prediction : [0.00034544]  Actual Value : 0
# Prediction : [0.01389609]  Actual Value : 0
# Prediction : [0.9652422]  Actual Value : 0
# Prediction : [4.345993e-05]  Actual Value : 0
# Prediction : [0.00261795]  Actual Value : 0
# Prediction : [0.0113424]  Actual Value : 1
# Prediction : [0.00029418]  Actual Value : 0
# Prediction : [0.6893638]  Actual Value : 1
# Prediction : [0.99955934]  Actual Value : 0
# Prediction : [0.9935457]  Actual Value : 0
# Prediction : [0.00016583]  Actual Value : 1
# Prediction : [0.90628517]  Actual Value : 1
# Prediction : [1.916445e-05]  Actual Value : 0
# Prediction : [0.00014283]  Actual Value : 1
# Prediction : [0.10926253]  Actual Value : 0
# Prediction : [0.19967587]  Actual Value : 1
# Prediction : [0.00199354]  Actual Value : 0
# Prediction : [5.3353113e-05]  Actual Value : 0
# Prediction : [0.7567017]  Actual Value : 1
# Prediction : [0.00023745]  Actual Value : 0
# Prediction : [0.99967396]  Actual Value : 0
# Prediction : [0.00461723]  Actual Value : 0
# Prediction : [0.01198904]  Actual Value : 1
# Prediction : [0.964587]  Actual Value : 0
# Prediction : [0.00194205]  Actual Value : 0
# Prediction : [3.1961015e-05]  Actual Value : 0
# Prediction : [0.51181704]  Actual Value : 0
# Prediction : [0.01123332]  Actual Value : 0
# Prediction : [0.01030525]  Actual Value : 0
# Prediction : [0.98718554]  Actual Value : 1
# Prediction : [0.00046198]  Actual Value : 0
# Prediction : [0.38638008]  Actual Value : 0
# Prediction : [0.00045362]  Actual Value : 0
# Prediction : [0.00289503]  Actual Value : 0
# Prediction : [0.01282198]  Actual Value : 0
# Prediction : [0.00149959]  Actual Value : 1
# Prediction : [0.00105321]  Actual Value : 0
# Prediction : [0.9895951]  Actual Value : 0
# Prediction : [0.01413836]  Actual Value : 1
# Prediction : [0.31731045]  Actual Value : 0
# Prediction : [1.660119e-05]  Actual Value : 0
# Prediction : [0.9999356]  Actual Value : 0
# Prediction : [0.0032753]  Actual Value : 0
# Prediction : [0.00954078]  Actual Value : 0
# Prediction : [0.06509715]  Actual Value : 0
# Prediction : [0.00036923]  Actual Value : 1
# Prediction : [0.03661008]  Actual Value : 1
# Prediction : [0.00058242]  Actual Value : 0
# Prediction : [0.8852674]  Actual Value : 0
# Prediction : [0.08778645]  Actual Value : 0
# Prediction : [0.6797186]  Actual Value : 0
# Prediction : [0.7528613]  Actual Value : 0
# Prediction : [0.00018402]  Actual Value : 0
# Prediction : [0.02758077]  Actual Value : 1
# Prediction : [0.8786681]  Actual Value : 0
# Prediction : [0.01061177]  Actual Value : 0
# Prediction : [0.01628117]  Actual Value : 0
# Prediction : [0.00049605]  Actual Value : 0
# Prediction : [0.00033588]  Actual Value : 0
# Prediction : [0.9649221]  Actual Value : 1
# Prediction : [0.0012337]  Actual Value : 0
# Prediction : [0.00014634]  Actual Value : 0
# Prediction : [0.98598194]  Actual Value : 0
# Prediction : [0.00040528]  Actual Value : 0
# Prediction : [0.00010082]  Actual Value : 0
# Prediction : [0.00041489]  Actual Value : 0
# Prediction : [0.988436]  Actual Value : 1
# Prediction : [0.00181821]  Actual Value : 1
# Prediction : [0.01547796]  Actual Value : 0
# Prediction : [0.04358504]  Actual Value : 0
# Prediction : [0.00026488]  Actual Value : 1
# Prediction : [0.01733006]  Actual Value : 0
# Prediction : [8.2573184e-05]  Actual Value : 0
# Prediction : [0.00658564]  Actual Value : 0
# Prediction : [0.29927716]  Actual Value : 0
# Prediction : [2.6338266e-05]  Actual Value : 0
# Prediction : [1.1949211e-06]  Actual Value : 0
# Prediction : [0.00034364]  Actual Value : 0
# Prediction : [0.00034235]  Actual Value : 0
# Prediction : [0.04552825]  Actual Value : 0
# Prediction : [0.15815307]  Actual Value : 0
# Prediction : [1.3109367e-06]  Actual Value : 0
# Prediction : [0.1391628]  Actual Value : 0
# Prediction : [0.00634556]  Actual Value : 0
# Prediction : [0.01195804]  Actual Value : 0
# Prediction : [0.4448468]  Actual Value : 1
# Prediction : [0.00049671]  Actual Value : 0
# Prediction : [0.00052318]  Actual Value : 0
# Prediction : [0.00245243]  Actual Value : 1
# Prediction : [5.4351687e-05]  Actual Value : 1
# Prediction : [0.01934295]  Actual Value : 1
# Prediction : [0.00141514]  Actual Value : 0
# Prediction : [0.9671714]  Actual Value : 0
# Prediction : [7.267186e-05]  Actual Value : 0
# Prediction : [0.17742676]  Actual Value : 0
# Prediction : [0.00201724]  Actual Value : 0
# Prediction : [0.00025161]  Actual Value : 0
# Prediction : [2.0783011e-06]  Actual Value : 0
# Prediction : [0.04430458]  Actual Value : 0
# Prediction : [0.73597246]  Actual Value : 0
# Prediction : [0.9994779]  Actual Value : 0
# Prediction : [0.6767426]  Actual Value : 0
# Prediction : [6.466031e-05]  Actual Value : 0
# Prediction : [0.00017056]  Actual Value : 0
# Prediction : [7.808474e-05]  Actual Value : 1
# Prediction : [0.13011461]  Actual Value : 1
# Prediction : [0.9851633]  Actual Value : 0
# Prediction : [0.79684854]  Actual Value : 0
# Prediction : [4.9030605e-06]  Actual Value : 0
# Prediction : [0.00381265]  Actual Value : 1
# Prediction : [3.508125e-05]  Actual Value : 0
# Prediction : [0.11232537]  Actual Value : 0
# Prediction : [0.00440838]  Actual Value : 1
# Prediction : [0.0105443]  Actual Value : 0
# Prediction : [0.01123494]  Actual Value : 0
# Prediction : [0.58764386]  Actual Value : 1
# Prediction : [0.00133198]  Actual Value : 0
# Prediction : [0.94537807]  Actual Value : 0
# Prediction : [0.08578021]  Actual Value : 1
# Prediction : [5.800602e-05]  Actual Value : 1
# Prediction : [4.9022907e-05]  Actual Value : 0
# Prediction : [1.7733157e-06]  Actual Value : 0
# Prediction : [6.1699655e-05]  Actual Value : 1
# Prediction : [0.000462]  Actual Value : 0
# Prediction : [0.74101454]  Actual Value : 1
# Prediction : [1.3235136e-06]  Actual Value : 0
# Prediction : [0.03361721]  Actual Value : 0
# Prediction : [5.888697e-05]  Actual Value : 0
# Prediction : [0.0064028]  Actual Value : 0
# Prediction : [0.00038672]  Actual Value : 0
# Prediction : [0.9987206]  Actual Value : 1
# Prediction : [0.02127644]  Actual Value : 0
# Prediction : [0.72285724]  Actual Value : 0
# Prediction : [0.00150404]  Actual Value : 0
# Prediction : [0.6748368]  Actual Value : 1
# Prediction : [0.00114719]  Actual Value : 0
# Prediction : [0.00082101]  Actual Value : 0
# Prediction : [0.00067061]  Actual Value : 0
# Prediction : [0.0402766]  Actual Value : 0
# Prediction : [0.00861418]  Actual Value : 1
# Prediction : [0.9567854]  Actual Value : 0
# Prediction : [0.09133732]  Actual Value : 1
# Prediction : [0.9632281]  Actual Value : 1
# Prediction : [0.99876773]  Actual Value : 1
# Prediction : [0.99707747]  Actual Value : 1
# Prediction : [0.9974003]  Actual Value : 0
# Prediction : [0.6097652]  Actual Value : 0
# Prediction : [0.9992091]  Actual Value : 0
# Prediction : [0.01197222]  Actual Value : 0
# Prediction : [0.69015867]  Actual Value : 0
# Prediction : [1.3034696e-05]  Actual Value : 0
# Prediction : [0.16701274]  Actual Value : 0
# Prediction : [0.00024259]  Actual Value : 0
# Prediction : [0.0010025]  Actual Value : 0
# Prediction : [0.0005351]  Actual Value : 0
# Prediction : [0.03706703]  Actual Value : 0
# Prediction : [0.992975]  Actual Value : 0
# Prediction : [0.5445963]  Actual Value : 0
# Prediction : [8.540503e-05]  Actual Value : 0
# Prediction : [0.06495661]  Actual Value : 0
# Prediction : [0.00015514]  Actual Value : 0
# Prediction : [0.00230503]  Actual Value : 0
# Prediction : [0.00125674]  Actual Value : 0
# Prediction : [0.00608523]  Actual Value : 0
# Prediction : [0.8389233]  Actual Value : 1
# Prediction : [8.598332e-06]  Actual Value : 0
# Prediction : [0.03680411]  Actual Value : 0
# Prediction : [0.00084239]  Actual Value : 0
# Prediction : [0.02059775]  Actual Value : 0
# Prediction : [0.00589181]  Actual Value : 0
# Prediction : [0.06937082]  Actual Value : 0
# Prediction : [0.84349954]  Actual Value : 0
# Prediction : [0.00013624]  Actual Value : 0
# Prediction : [1.2142848e-05]  Actual Value : 0
# Prediction : [2.3371742e-05]  Actual Value : 0
# Prediction : [0.03551895]  Actual Value : 1
# Prediction : [0.00208675]  Actual Value : 0
# Prediction : [0.00344881]  Actual Value : 0
# Prediction : [0.5937284]  Actual Value : 0
# Prediction : [4.0554954e-05]  Actual Value : 0
# Prediction : [0.00715722]  Actual Value : 0
# Prediction : [0.9867822]  Actual Value : 1
# Prediction : [2.0046686e-05]  Actual Value : 0
# Prediction : [0.31587738]  Actual Value : 0
# Prediction : [3.3045013e-05]  Actual Value : 0
# Prediction : [0.00612479]  Actual Value : 0
# Prediction : [0.0010848]  Actual Value : 0
# Prediction : [3.5675297e-05]  Actual Value : 0
# Prediction : [0.00132489]  Actual Value : 0
# Prediction : [0.4471813]  Actual Value : 0
# Prediction : [0.01588242]  Actual Value : 0
# Prediction : [0.0001707]  Actual Value : 1
# Prediction : [0.23928662]  Actual Value : 0
# Prediction : [1.7375747e-05]  Actual Value : 1
# Prediction : [6.9835405e-05]  Actual Value : 0
# Prediction : [1.1690729e-05]  Actual Value : 0
# Prediction : [1.7020855e-05]  Actual Value : 0
# Prediction : [3.6806487e-05]  Actual Value : 0
# Prediction : [0.01201692]  Actual Value : 0
# Prediction : [1.5992313e-05]  Actual Value : 1
# Prediction : [4.3946707e-06]  Actual Value : 1
# Prediction : [0.00020464]  Actual Value : 0
# Prediction : [8.7752764e-05]  Actual Value : 0
# Prediction : [0.20879032]  Actual Value : 1
# Prediction : [3.0475538e-05]  Actual Value : 0
# Prediction : [0.00021685]  Actual Value : 0
# Prediction : [0.02430249]  Actual Value : 0
# Prediction : [0.02768618]  Actual Value : 0
# Prediction : [0.00070055]  Actual Value : 0
# Prediction : [0.00023994]  Actual Value : 0
# Prediction : [0.32547954]  Actual Value : 0
# Prediction : [0.067143]  Actual Value : 1
# Prediction : [0.00188556]  Actual Value : 1
# Prediction : [0.017948]  Actual Value : 0
# Prediction : [0.24454561]  Actual Value : 0
# Prediction : [3.5810997e-05]  Actual Value : 1
# Prediction : [2.975937e-07]  Actual Value : 0
# Prediction : [0.00088448]  Actual Value : 0
# Prediction : [0.11575197]  Actual Value : 0
# Prediction : [0.05212212]  Actual Value : 0
# Prediction : [0.06635986]  Actual Value : 1
# Prediction : [0.01099066]  Actual Value : 0
# Prediction : [0.39489466]  Actual Value : 1
# Prediction : [0.0229998]  Actual Value : 0
# Prediction : [0.01186865]  Actual Value : 0
# Prediction : [0.00014207]  Actual Value : 0
# Prediction : [0.05801739]  Actual Value : 0
# Prediction : [0.01339701]  Actual Value : 0
# Prediction : [1.8729141e-06]  Actual Value : 0
# Prediction : [0.02719631]  Actual Value : 1
# Prediction : [0.09143413]  Actual Value : 0
# Prediction : [0.00946088]  Actual Value : 0
# Prediction : [8.49992e-05]  Actual Value : 0
# Prediction : [0.9826585]  Actual Value : 0
# Prediction : [0.00052616]  Actual Value : 0
# Prediction : [0.9999399]  Actual Value : 0
# Prediction : [0.0164526]  Actual Value : 0
# Prediction : [0.23048666]  Actual Value : 0
# Prediction : [0.00027854]  Actual Value : 0
# Prediction : [0.45283377]  Actual Value : 1
# Prediction : [0.08844708]  Actual Value : 0
# Prediction : [0.13165519]  Actual Value : 0
# Prediction : [0.02317344]  Actual Value : 0
# Prediction : [1.7222451e-06]  Actual Value : 1
# Prediction : [0.0044458]  Actual Value : 0
# Prediction : [0.00081952]  Actual Value : 0
# Prediction : [1.8262981e-06]  Actual Value : 0
# Prediction : [0.9971103]  Actual Value : 0
# Prediction : [0.95881873]  Actual Value : 0
# Prediction : [6.0613064e-07]  Actual Value : 0
# Prediction : [7.1005757e-06]  Actual Value : 0
# Prediction : [0.96203756]  Actual Value : 0
# Prediction : [3.5281413e-05]  Actual Value : 0
# Prediction : [2.5548867e-05]  Actual Value : 1
# Prediction : [0.9792733]  Actual Value : 0
# Prediction : [0.02474893]  Actual Value : 1
# Prediction : [0.06462219]  Actual Value : 1
# Prediction : [0.00069837]  Actual Value : 1
# Prediction : [0.02198416]  Actual Value : 0
# Prediction : [8.416521e-06]  Actual Value : 1
# Prediction : [2.869488e-05]  Actual Value : 0
# Prediction : [0.999689]  Actual Value : 0
# Prediction : [0.00136437]  Actual Value : 1
# Prediction : [0.07545815]  Actual Value : 0
# Prediction : [6.9716094e-05]  Actual Value : 0
# Prediction : [2.5097117e-07]  Actual Value : 0
# Prediction : [0.00075919]  Actual Value : 0
# Prediction : [6.058167e-06]  Actual Value : 0
# Prediction : [4.3647e-05]  Actual Value : 1
# Prediction : [0.000393]  Actual Value : 0
# Prediction : [0.99595416]  Actual Value : 1
# Prediction : [0.89937323]  Actual Value : 0
# Prediction : [0.7510515]  Actual Value : 0
# Prediction : [0.00105409]  Actual Value : 0
# Prediction : [0.0050066]  Actual Value : 1
# Prediction : [0.9302839]  Actual Value : 1
# Prediction : [0.01211522]  Actual Value : 0
# Prediction : [0.32716435]  Actual Value : 0
# Prediction : [0.02174987]  Actual Value : 1
# Prediction : [0.00477973]  Actual Value : 1
# Prediction : [0.00032347]  Actual Value : 0
# Prediction : [6.2398294e-06]  Actual Value : 1
# Prediction : [0.03028288]  Actual Value : 1
# Prediction : [7.533932e-05]  Actual Value : 0
# Prediction : [0.5102658]  Actual Value : 0
# Prediction : [0.00534377]  Actual Value : 1
# Prediction : [0.12007981]  Actual Value : 0
# Prediction : [3.4827248e-05]  Actual Value : 1
# Prediction : [0.98967534]  Actual Value : 0
# Prediction : [0.15264271]  Actual Value : 0
# Prediction : [2.1536792e-07]  Actual Value : 0
# Prediction : [2.1378706e-05]  Actual Value : 0
# Prediction : [0.39525804]  Actual Value : 0
# Prediction : [5.089112e-06]  Actual Value : 0
# Prediction : [0.0678744]  Actual Value : 1
# Prediction : [0.00064316]  Actual Value : 0
# Prediction : [0.01795725]  Actual Value : 0
# Prediction : [0.9046388]  Actual Value : 0
# Prediction : [0.9867764]  Actual Value : 0
# Prediction : [0.00012494]  Actual Value : 0
# Prediction : [0.23149428]  Actual Value : 1
# Prediction : [0.00113847]  Actual Value : 0
# Prediction : [0.3407128]  Actual Value : 0
# Prediction : [0.75879997]  Actual Value : 0
# Prediction : [0.99999297]  Actual Value : 0
# Prediction : [0.00143472]  Actual Value : 0
# Prediction : [0.4071908]  Actual Value : 0
# Prediction : [0.00204736]  Actual Value : 0
# Prediction : [0.14382738]  Actual Value : 1
# Prediction : [0.9796056]  Actual Value : 0
# Prediction : [0.00054629]  Actual Value : 0
# Prediction : [0.00207064]  Actual Value : 0
# Prediction : [0.00021285]  Actual Value : 0
# Prediction : [5.7367274e-06]  Actual Value : 0
# Prediction : [0.0001535]  Actual Value : 0
# Prediction : [0.00560173]  Actual Value : 1
# Prediction : [1.2630152e-06]  Actual Value : 0
# Prediction : [1.0862857e-06]  Actual Value : 0
# Prediction : [0.00045429]  Actual Value : 0
# Prediction : [0.4328902]  Actual Value : 1
# Prediction : [0.01038338]  Actual Value : 0
# Prediction : [0.00055753]  Actual Value : 0
# Prediction : [5.307475e-06]  Actual Value : 0
# Prediction : [4.0814084e-05]  Actual Value : 0
# Prediction : [5.1639014e-05]  Actual Value : 0
# Prediction : [0.02423466]  Actual Value : 0
# Prediction : [1.4511779e-05]  Actual Value : 0
# Prediction : [8.305221e-05]  Actual Value : 0
# Prediction : [0.01024875]  Actual Value : 0
# Prediction : [0.77052355]  Actual Value : 0
# Prediction : [0.0071121]  Actual Value : 0
# Prediction : [9.110956e-06]  Actual Value : 0
# Prediction : [0.9905566]  Actual Value : 1
# Prediction : [1.5345619e-05]  Actual Value : 1
# Prediction : [0.75716853]  Actual Value : 1
# Prediction : [0.1012963]  Actual Value : 1
# Prediction : [0.30052364]  Actual Value : 0
# Prediction : [0.0036544]  Actual Value : 0
# Prediction : [0.03692666]  Actual Value : 1
# Prediction : [0.00041893]  Actual Value : 0
# Prediction : [0.09422118]  Actual Value : 1
# Prediction : [9.190542e-05]  Actual Value : 0
# Prediction : [1.1943378e-06]  Actual Value : 1
# Prediction : [0.00039579]  Actual Value : 0
# Prediction : [0.47652873]  Actual Value : 0
# Prediction : [0.9587022]  Actual Value : 0
# Prediction : [0.9727561]  Actual Value : 0
# Prediction : [0.00144658]  Actual Value : 0
# Prediction : [0.9701295]  Actual Value : 1
# Prediction : [0.16742893]  Actual Value : 0
# Prediction : [0.0066678]  Actual Value : 0
# Prediction : [0.01922452]  Actual Value : 0
# Prediction : [0.00321022]  Actual Value : 0
# Prediction : [0.73093885]  Actual Value : 0
# Prediction : [0.05377458]  Actual Value : 1
# Prediction : [0.99340785]  Actual Value : 0
# Prediction : [0.00041296]  Actual Value : 0
# Prediction : [4.9527764e-05]  Actual Value : 0
# Prediction : [0.00043204]  Actual Value : 1
# Prediction : [0.41906497]  Actual Value : 1
# Prediction : [1.8484307e-05]  Actual Value : 0
# Prediction : [0.03657909]  Actual Value : 0
# Prediction : [0.00010102]  Actual Value : 0
# Prediction : [0.8406343]  Actual Value : 0
# Prediction : [0.01907338]  Actual Value : 0
# Prediction : [0.9995741]  Actual Value : 0
# Prediction : [0.94514775]  Actual Value : 1
# Prediction : [0.7449849]  Actual Value : 1
# Prediction : [0.00076333]  Actual Value : 0
# Prediction : [0.00166241]  Actual Value : 0
# Prediction : [0.02514711]  Actual Value : 0
# Prediction : [0.01130853]  Actual Value : 0
# Prediction : [0.08081981]  Actual Value : 0
# Prediction : [0.08116189]  Actual Value : 0
# Prediction : [0.02461077]  Actual Value : 0
# Prediction : [0.00037259]  Actual Value : 0
# Prediction : [1.1995967e-06]  Actual Value : 1
# Prediction : [7.292752e-08]  Actual Value : 0
# Prediction : [0.00092617]  Actual Value : 0
# Prediction : [1.2789608e-05]  Actual Value : 1
# Prediction : [0.00018711]  Actual Value : 1
# Prediction : [0.02729554]  Actual Value : 0
# Prediction : [0.00047748]  Actual Value : 0
# Prediction : [0.0457553]  Actual Value : 0
# Prediction : [0.542344]  Actual Value : 0
# Prediction : [0.00026757]  Actual Value : 1
# Prediction : [0.73052484]  Actual Value : 1
# Prediction : [0.01111511]  Actual Value : 0
# Prediction : [0.9996481]  Actual Value : 0
# Prediction : [0.83105123]  Actual Value : 0
# Prediction : [0.00032695]  Actual Value : 0
# Prediction : [0.00557118]  Actual Value : 0
# Prediction : [0.97345304]  Actual Value : 0
# Prediction : [0.00126912]  Actual Value : 0
# Prediction : [0.51167935]  Actual Value : 1
# Prediction : [0.01615316]  Actual Value : 0
# Prediction : [0.98904294]  Actual Value : 0
# Prediction : [0.01153592]  Actual Value : 0
# Prediction : [1.5470354e-07]  Actual Value : 0
# Prediction : [0.81249297]  Actual Value : 1
# Prediction : [0.9942601]  Actual Value : 0
# Prediction : [0.01127912]  Actual Value : 1
# Prediction : [1.8085724e-06]  Actual Value : 0
# Prediction : [0.00031962]  Actual Value : 1
# Prediction : [0.00053564]  Actual Value : 0
# Prediction : [0.05582636]  Actual Value : 0
# Prediction : [5.903913e-07]  Actual Value : 1
# Prediction : [5.2308513e-07]  Actual Value : 0
# Prediction : [0.00136695]  Actual Value : 0
# Prediction : [0.07514188]  Actual Value : 0
# Prediction : [7.4742597e-06]  Actual Value : 0
# Prediction : [1.6262577e-06]  Actual Value : 0
# Prediction : [0.9000836]  Actual Value : 0
# Prediction : [0.6178442]  Actual Value : 0
# Prediction : [0.00311516]  Actual Value : 0
# Prediction : [7.906533e-05]  Actual Value : 0
# Prediction : [0.9881166]  Actual Value : 0
# Prediction : [0.7588004]  Actual Value : 0
# Prediction : [0.01007391]  Actual Value : 0
# Prediction : [0.01572042]  Actual Value : 0
# Prediction : [0.32295984]  Actual Value : 1
# Prediction : [0.02269213]  Actual Value : 0
# Prediction : [0.00494529]  Actual Value : 0
# Prediction : [0.00021588]  Actual Value : 0
# Prediction : [0.00015317]  Actual Value : 0
# Prediction : [1.1102436e-06]  Actual Value : 0
# Prediction : [7.572821e-05]  Actual Value : 0
# Prediction : [0.7714573]  Actual Value : 1
# Prediction : [0.14171627]  Actual Value : 1
# Prediction : [0.05445756]  Actual Value : 0
# Prediction : [0.95090175]  Actual Value : 0
# Prediction : [0.00015338]  Actual Value : 1
# Prediction : [0.00351227]  Actual Value : 1
# Prediction : [0.05108467]  Actual Value : 0
# Prediction : [0.00010116]  Actual Value : 0
# Prediction : [0.01529941]  Actual Value : 1
# Prediction : [0.00461838]  Actual Value : 0
# Prediction : [0.00034595]  Actual Value : 0
# Prediction : [0.00114226]  Actual Value : 1
# Prediction : [0.0232489]  Actual Value : 0
# Prediction : [0.83676004]  Actual Value : 0
# Prediction : [0.9109272]  Actual Value : 1
# Prediction : [1.510755e-05]  Actual Value : 1
# Prediction : [0.00171313]  Actual Value : 0
# Prediction : [0.0014345]  Actual Value : 0
# Prediction : [0.09536155]  Actual Value : 0
# Prediction : [0.09487978]  Actual Value : 1
# Prediction : [0.00040186]  Actual Value : 0
# Prediction : [0.30454767]  Actual Value : 0
# Prediction : [0.00046937]  Actual Value : 1
# Prediction : [0.0003267]  Actual Value : 1
# Prediction : [0.96108276]  Actual Value : 0
# Prediction : [0.11810037]  Actual Value : 0
# Prediction : [0.9707295]  Actual Value : 0
# Prediction : [0.00321981]  Actual Value : 0
# Prediction : [0.00027741]  Actual Value : 0
# Prediction : [0.00531481]  Actual Value : 0
# Prediction : [0.00023613]  Actual Value : 0
# Prediction : [0.9368549]  Actual Value : 1
# Prediction : [5.817988e-06]  Actual Value : 0
# Prediction : [0.00319245]  Actual Value : 0
# Prediction : [0.00305183]  Actual Value : 1
# Prediction : [0.00490006]  Actual Value : 0
# Prediction : [0.00039772]  Actual Value : 0
# Prediction : [0.00952921]  Actual Value : 0
# Prediction : [0.01107063]  Actual Value : 1
# Prediction : [0.04507406]  Actual Value : 0
# Prediction : [0.05369309]  Actual Value : 0
# Prediction : [0.01560545]  Actual Value : 0
# Prediction : [0.89822847]  Actual Value : 0
# Prediction : [0.94636834]  Actual Value : 0
# Prediction : [2.1218673e-05]  Actual Value : 1
# Prediction : [7.6382246e-05]  Actual Value : 0
# Prediction : [0.33893535]  Actual Value : 1
# Prediction : [6.3145085e-06]  Actual Value : 0
# Prediction : [0.03048095]  Actual Value : 1
# Prediction : [0.01140781]  Actual Value : 0
# Prediction : [0.4239731]  Actual Value : 0
# Prediction : [0.05546408]  Actual Value : 1
# Prediction : [0.01676575]  Actual Value : 0
# Prediction : [0.0715192]  Actual Value : 0
# Prediction : [0.9968545]  Actual Value : 0
# Prediction : [0.00046513]  Actual Value : 1
# Prediction : [0.47635674]  Actual Value : 0
# Prediction : [0.00018617]  Actual Value : 1
# Prediction : [0.02403483]  Actual Value : 0
# Prediction : [0.00299455]  Actual Value : 1
# Prediction : [0.00829664]  Actual Value : 0
# Prediction : [0.0147156]  Actual Value : 1
# Prediction : [0.62158465]  Actual Value : 0
# Prediction : [0.22345972]  Actual Value : 0
# Prediction : [0.00371084]  Actual Value : 0
# Prediction : [6.4677783e-06]  Actual Value : 0
# Prediction : [7.700654e-06]  Actual Value : 1
# Prediction : [0.00151942]  Actual Value : 0
# Prediction : [0.05774559]  Actual Value : 0
# Prediction : [0.00134772]  Actual Value : 1
# Prediction : [0.0004577]  Actual Value : 0
# Prediction : [0.00052698]  Actual Value : 0
# Prediction : [0.8024149]  Actual Value : 1
# Prediction : [1.9498253e-05]  Actual Value : 0
# Prediction : [0.00313778]  Actual Value : 0
# Prediction : [1.14115196e-07]  Actual Value : 1
# Prediction : [0.00093042]  Actual Value : 1
# Prediction : [0.00012217]  Actual Value : 0
# Prediction : [0.9999888]  Actual Value : 0
# Prediction : [3.9949473e-06]  Actual Value : 1
# Prediction : [0.01206494]  Actual Value : 0
# Prediction : [0.00051228]  Actual Value : 0
# Prediction : [1.0191036e-05]  Actual Value : 0
# Prediction : [0.989287]  Actual Value : 0
# Prediction : [0.00250198]  Actual Value : 0
# Prediction : [0.99582505]  Actual Value : 0
# Prediction : [0.00061688]  Actual Value : 1
# Prediction : [0.01705648]  Actual Value : 0
# Prediction : [0.99759537]  Actual Value : 1
# Prediction : [0.33908176]  Actual Value : 0
# Prediction : [4.1352184e-08]  Actual Value : 0
# Prediction : [4.1262922e-07]  Actual Value : 0
# Prediction : [7.9759746e-05]  Actual Value : 0
# Prediction : [0.0016139]  Actual Value : 0
# Prediction : [0.00025764]  Actual Value : 0
# Prediction : [0.00015789]  Actual Value : 0
# Prediction : [0.00038161]  Actual Value : 0
# Prediction : [0.6094265]  Actual Value : 0
# Prediction : [0.02499815]  Actual Value : 1
# Prediction : [0.0864178]  Actual Value : 0
# Prediction : [0.6563369]  Actual Value : 1
# Prediction : [0.00811205]  Actual Value : 0
# Prediction : [0.5957892]  Actual Value : 1
# Prediction : [0.00042146]  Actual Value : 0
# Prediction : [0.05463154]  Actual Value : 0
# Prediction : [1.5948328e-05]  Actual Value : 1
# Prediction : [0.0001188]  Actual Value : 0
# Prediction : [0.00018853]  Actual Value : 1
# Prediction : [0.00016929]  Actual Value : 0
# Prediction : [0.9475785]  Actual Value : 1
# Prediction : [3.5725554e-06]  Actual Value : 0
# Prediction : [0.00975529]  Actual Value : 0
# Prediction : [0.00035575]  Actual Value : 0
# Prediction : [0.00066503]  Actual Value : 0
# Prediction : [0.07182252]  Actual Value : 0
# Prediction : [0.91633147]  Actual Value : 1
# Prediction : [6.7558227e-07]  Actual Value : 0
# Prediction : [0.6308561]  Actual Value : 0
# Prediction : [0.00269221]  Actual Value : 1
# Prediction : [0.0002035]  Actual Value : 0
# Prediction : [0.00229212]  Actual Value : 0
# Prediction : [0.26791045]  Actual Value : 0
# Prediction : [2.6175514e-06]  Actual Value : 0
# Prediction : [8.455338e-06]  Actual Value : 0
# Prediction : [1.4768194e-07]  Actual Value : 0
# Prediction : [0.8251973]  Actual Value : 0
# Prediction : [0.99839634]  Actual Value : 0
# Prediction : [6.0579663e-05]  Actual Value : 0
# Prediction : [0.00403304]  Actual Value : 0
# Prediction : [2.9141824e-05]  Actual Value : 0
# Prediction : [4.1894296e-07]  Actual Value : 0
# Prediction : [2.4739275e-05]  Actual Value : 1
# Prediction : [0.00779603]  Actual Value : 0
# Prediction : [0.05042503]  Actual Value : 0
# Prediction : [0.00012712]  Actual Value : 0
# Prediction : [0.37542614]  Actual Value : 0
# Prediction : [0.00556571]  Actual Value : 0
# Prediction : [0.0027958]  Actual Value : 1
# Prediction : [0.09597734]  Actual Value : 0
# Prediction : [0.9879226]  Actual Value : 0
# Prediction : [0.00094114]  Actual Value : 0
# Prediction : [3.575094e-05]  Actual Value : 0
# Prediction : [0.7219564]  Actual Value : 0
# Prediction : [0.00016463]  Actual Value : 0
# Prediction : [0.00017621]  Actual Value : 1
# Prediction : [0.7948801]  Actual Value : 0
# Prediction : [0.00046317]  Actual Value : 0
# Prediction : [2.2682842e-05]  Actual Value : 1
# Prediction : [0.0002136]  Actual Value : 0
# Prediction : [0.00065862]  Actual Value : 0
# Prediction : [0.00014826]  Actual Value : 0
# Prediction : [0.00387287]  Actual Value : 0
# Prediction : [0.4443868]  Actual Value : 0
# Prediction : [6.5127088e-06]  Actual Value : 0
# Prediction : [0.99992776]  Actual Value : 0
# Prediction : [3.761872e-05]  Actual Value : 0
# Prediction : [0.00090132]  Actual Value : 0
# Prediction : [0.00745065]  Actual Value : 0
# Prediction : [0.81422335]  Actual Value : 0
# Prediction : [0.0009319]  Actual Value : 1
# Prediction : [0.00038593]  Actual Value : 0
# Prediction : [0.739862]  Actual Value : 1
# Prediction : [0.00045936]  Actual Value : 0
# Prediction : [0.00058224]  Actual Value : 0
# Prediction : [0.42035308]  Actual Value : 1
# Prediction : [0.00199626]  Actual Value : 0
# Prediction : [2.7115215e-05]  Actual Value : 0
# Prediction : [0.00136279]  Actual Value : 0
# Prediction : [3.6411184e-05]  Actual Value : 0
# Prediction : [1.6013113e-05]  Actual Value : 0
# Prediction : [3.3763722e-06]  Actual Value : 0
# Prediction : [0.9905302]  Actual Value : 0
# Prediction : [3.4158536e-05]  Actual Value : 0
# Prediction : [0.00326465]  Actual Value : 0
# Prediction : [6.818642e-08]  Actual Value : 1
# Prediction : [0.21273206]  Actual Value : 0
# Prediction : [0.9183022]  Actual Value : 0
# Prediction : [0.00039813]  Actual Value : 1
# Prediction : [3.7373343e-07]  Actual Value : 0
# Prediction : [0.01001153]  Actual Value : 1
# Prediction : [0.00425264]  Actual Value : 0
# Prediction : [0.14442983]  Actual Value : 0
# Prediction : [0.00286836]  Actual Value : 1
# Prediction : [0.0023796]  Actual Value : 0
# Prediction : [0.5106238]  Actual Value : 1
# Prediction : [0.00024129]  Actual Value : 0
# Prediction : [0.55393547]  Actual Value : 1
# Prediction : [0.03576788]  Actual Value : 0
# Prediction : [0.00224865]  Actual Value : 0
# Prediction : [3.4478703e-07]  Actual Value : 0
# Prediction : [0.9823813]  Actual Value : 0
# Prediction : [7.865809e-06]  Actual Value : 1
# Prediction : [0.0004294]  Actual Value : 0
# Prediction : [0.00576611]  Actual Value : 0
# Prediction : [0.00113698]  Actual Value : 0
# Prediction : [0.00356034]  Actual Value : 0
# Prediction : [0.999495]  Actual Value : 0
# Prediction : [0.9606061]  Actual Value : 0
# Prediction : [1.4769224e-06]  Actual Value : 0
# Prediction : [0.00020772]  Actual Value : 1
# Prediction : [1.3618364e-05]  Actual Value : 0
# Prediction : [0.01827053]  Actual Value : 1
# Prediction : [0.9962451]  Actual Value : 0
# Prediction : [6.5919754e-05]  Actual Value : 0
# Prediction : [0.03474003]  Actual Value : 0
# Prediction : [0.9129608]  Actual Value : 0
# Prediction : [0.0040185]  Actual Value : 0
# Prediction : [0.00288764]  Actual Value : 0
# Prediction : [0.22472465]  Actual Value : 0
# Prediction : [2.556054e-05]  Actual Value : 0
# Prediction : [1.216515e-06]  Actual Value : 1
# Prediction : [1.2315169e-05]  Actual Value : 0
# Prediction : [1.3835075e-05]  Actual Value : 0
# Prediction : [0.00154421]  Actual Value : 0
# Prediction : [0.00511767]  Actual Value : 1
# Prediction : [6.909943e-05]  Actual Value : 0
# Prediction : [0.00022449]  Actual Value : 0
# Prediction : [0.999316]  Actual Value : 1
# Prediction : [0.04932191]  Actual Value : 0
# Prediction : [0.9999453]  Actual Value : 0
# Prediction : [6.8398936e-06]  Actual Value : 0
# Prediction : [0.89571637]  Actual Value : 1
# Prediction : [0.0090964]  Actual Value : 0
# Prediction : [0.07386377]  Actual Value : 0
# Prediction : [0.00042235]  Actual Value : 0
# Prediction : [0.00066613]  Actual Value : 0
# Prediction : [8.6350316e-05]  Actual Value : 0
# Prediction : [0.00037315]  Actual Value : 0
# Prediction : [1.8829716e-05]  Actual Value : 0
# Prediction : [0.4482867]  Actual Value : 0
# Prediction : [0.00014825]  Actual Value : 0
# Prediction : [8.0639e-05]  Actual Value : 0
# Prediction : [0.0004187]  Actual Value : 1
# Prediction : [0.18675147]  Actual Value : 0
# Prediction : [0.9653968]  Actual Value : 1
# Prediction : [0.10713497]  Actual Value : 0
# Prediction : [0.98287994]  Actual Value : 0
# Prediction : [0.02463143]  Actual Value : 0
# Prediction : [2.6411866e-05]  Actual Value : 1
# Prediction : [4.6847717e-06]  Actual Value : 0
# Prediction : [5.576526e-06]  Actual Value : 0
# Prediction : [0.99982494]  Actual Value : 0
# Prediction : [0.10011273]  Actual Value : 0
# Prediction : [0.60247666]  Actual Value : 0
# Prediction : [0.9423309]  Actual Value : 0
# Prediction : [0.05015786]  Actual Value : 0
# Prediction : [0.989516]  Actual Value : 1
# Prediction : [1.2830362e-05]  Actual Value : 0
# Prediction : [0.13555089]  Actual Value : 0
# Prediction : [1.4411899e-07]  Actual Value : 0
# Prediction : [0.00336429]  Actual Value : 0
# Prediction : [0.9508445]  Actual Value : 0
# Prediction : [0.00042115]  Actual Value : 0
# Prediction : [0.10827861]  Actual Value : 0
# Prediction : [0.00010662]  Actual Value : 0
# Prediction : [6.328656e-05]  Actual Value : 0
# Prediction : [0.05358319]  Actual Value : 0
# Prediction : [0.06977087]  Actual Value : 0
# Prediction : [0.0013559]  Actual Value : 0
# Prediction : [7.233977e-05]  Actual Value : 1
# Prediction : [0.00065706]  Actual Value : 0
# Prediction : [0.9903307]  Actual Value : 1
# Prediction : [0.76536214]  Actual Value : 0
# Prediction : [0.04136171]  Actual Value : 1
# Prediction : [0.00407358]  Actual Value : 0
# Prediction : [0.9916032]  Actual Value : 0
# Prediction : [1.4669708e-05]  Actual Value : 1
# Prediction : [0.00048542]  Actual Value : 0
# Prediction : [1.8474137e-05]  Actual Value : 0
# Prediction : [0.02704171]  Actual Value : 0
# Prediction : [0.00642581]  Actual Value : 0
# Prediction : [0.02331607]  Actual Value : 0
# Prediction : [0.00100267]  Actual Value : 0
# Prediction : [0.00043451]  Actual Value : 0
# Prediction : [6.670814e-07]  Actual Value : 0
# Prediction : [0.00792602]  Actual Value : 0
# Prediction : [9.998787e-06]  Actual Value : 0
# Prediction : [0.00581703]  Actual Value : 0
# Prediction : [0.00019593]  Actual Value : 0
# Prediction : [0.0022648]  Actual Value : 0
# Prediction : [0.00127923]  Actual Value : 0
# Prediction : [0.9993319]  Actual Value : 0
# Prediction : [0.00491396]  Actual Value : 0
# Prediction : [0.00156458]  Actual Value : 1
# Prediction : [1.843934e-07]  Actual Value : 1
# Prediction : [0.00398436]  Actual Value : 0
# Prediction : [0.00010866]  Actual Value : 0
# Prediction : [8.152259e-05]  Actual Value : 0
# Prediction : [0.99488884]  Actual Value : 0
# Prediction : [3.43164e-05]  Actual Value : 0
# Prediction : [0.06787042]  Actual Value : 0
# Prediction : [0.01136167]  Actual Value : 0
# Prediction : [3.1570098e-06]  Actual Value : 0
# Prediction : [0.11285335]  Actual Value : 1
# Prediction : [0.09847876]  Actual Value : 0
# Prediction : [0.3564418]  Actual Value : 0
# Prediction : [0.86352694]  Actual Value : 0
# Prediction : [0.00315403]  Actual Value : 0
# Prediction : [1.1504229e-06]  Actual Value : 0
# Prediction : [3.6574053e-05]  Actual Value : 1
# Prediction : [0.00012261]  Actual Value : 0
# Prediction : [0.00055592]  Actual Value : 1
# Prediction : [0.9601866]  Actual Value : 0
# Prediction : [0.00370467]  Actual Value : 1
# Prediction : [0.00384882]  Actual Value : 0
# Prediction : [0.03899385]  Actual Value : 0
# Prediction : [0.00019713]  Actual Value : 0
# Prediction : [5.0943632e-05]  Actual Value : 0
# Prediction : [0.00401637]  Actual Value : 0
# Prediction : [0.98264885]  Actual Value : 1
# Prediction : [0.00045487]  Actual Value : 0
# Prediction : [0.00026033]  Actual Value : 1
# Prediction : [0.00967441]  Actual Value : 0
# Prediction : [0.00363563]  Actual Value : 0
# Prediction : [4.0051436e-06]  Actual Value : 0
# Prediction : [0.9634747]  Actual Value : 0
# Prediction : [0.03355822]  Actual Value : 0
# Prediction : [0.00078769]  Actual Value : 0
# Prediction : [0.9923361]  Actual Value : 0
# Prediction : [0.00398813]  Actual Value : 0
# Prediction : [0.00493457]  Actual Value : 0
# Prediction : [0.5003619]  Actual Value : 1
# Prediction : [0.30923882]  Actual Value : 0
# Prediction : [0.9995573]  Actual Value : 1

# %%
# plotting Accuracy
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# %%
# plotting Losshistory
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='lower right')
