# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import re
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import stopwords 
from nltk import word_tokenize
from keras.models import Model
from keras.layers import Dense, Input, Dropout, LSTM, Activation,concatenate,Bidirectional,BatchNormalization, Lambda, Layer
from keras.initializers import Constant
import keras.backend as K
from keras.layers.embeddings import Embedding
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
import emoji
# Out:
# Using TensorFlow backend.

# %%
print(tf.__version__)
print(tf.test.gpu_device_name())
# Out:
# 2.1.0
# /device:GPU:0

# %%
RANDOM_SEED = 42

np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# %%
data = pd.read_csv("./dataset/dataset.csv")
print(data.head())
# Out:
#    type                                              posts
# 0  INFJ  'http://www.youtube.com/watch?v=qsXHcwe3krw|||...
# 1  ENTP  'I'm finding the lack of me in these posts ver...
# 2  INTP  'Good one  _____   https://www.youtube.com/wat...
# 3  INTJ  'Dear INTP,   I enjoyed our conversation the o...
# 4  ENTJ  'You're fired.|||That's another silly misconce...

# %%
def char_is_emoji(character):
    return character in emoji.UNICODE_EMOJI

def text_has_emoji(text):
    return(bool(emoji.get_emoji_regexp().search(text)))

def returnEmojis(text):
    listEmojis=[]
    for c in text:
        if (char_is_emoji(c)):
            listEmojis.append(c)
    return(listEmojis)

# %%
# Add features to DataFrame
'''data['words_per_comment'] = data['posts'].apply(lambda x: len(x.split())/50)
data['question_per_comment'] = data['posts'].apply(lambda x: x.count('?')/50)
data['excl_per_comment'] = data['posts'].apply(lambda x: x.count('!')/50)
data['ellipsis_per_comment'] = data['posts'].apply(lambda x: x.count('...')/50)
#data['@_per_comment'] = data['posts'].apply(lambda x: x.count('@')/50)
#data['#_per_comment'] = data['posts'].apply(lambda x: x.count('#')/50)
data['emojis_per_comment'] = data['posts'].apply(lambda x: (len(returnEmojis(x)))/50)
print(data.head())
data.shape'''
# Out:
# "data['words_per_comment'] = data['posts'].apply(lambda x: len(x.split())/50)\ndata['question_per_comment'] = data['posts'].apply(lambda x: x.count('?')/50)\ndata['excl_per_comment'] = data['posts'].apply(lambda x: x.count('!')/50)\ndata['ellipsis_per_comment'] = data['posts'].apply(lambda x: x.count('...')/50)\n#data['@_per_comment'] = data['posts'].apply(lambda x: x.count('@')/50)\n#data['#_per_comment'] = data['posts'].apply(lambda x: x.count('#')/50)\ndata['emojis_per_comment'] = data['posts'].apply(lambda x: (len(returnEmojis(x)))/50)\nprint(data.head())\ndata.shape"

# %%
full_Pers_list = {'INFP' :0 ,'INTJ' :1 ,'INFJ' :2, 'INTP' :3 ,'ENFP' :4 ,'ENTJ' :5, 'ENTP' :6 ,'ENFJ' :7, 'ISFJ' :8 ,'ISFP' :9 ,'ISTJ' :10 ,'ISTP' :11 ,'ESFJ' :12,'ESFP' :13 ,'ESTJ' :14 ,'ESTP' :15}
def type_to_16(typeList):
    labels=[]
    for t in typeList:
        labels.append(full_Pers_list[t])
    return(labels)

def type16_to_vector_label(data):
    for i,label in enumerate(data):
        translation=np.zeros((16))
        translation[int(label)]=1
        data[i]=translation
        
labels=type_to_16(data["type"])
data["labels"]=labels
data.tail()
# Out:
#       type                                              posts  labels
# 8670  ISFP  'https://www.youtube.com/watch?v=t8edHB_h908||...       9
# 8671  ENFP  'So...if this thread already exists someplace ...       4
# 8672  INTP  'So many questions when i do these things.  I ...       3
# 8673  INFP  'I am very conflicted right now when it comes ...       0
# 8674  INFP  'It has been too long since I have been on per...       0

# %%
b_Pers = {'I':0, 'E':1, 'N':0, 'S':1, 'F':0, 'T':1, 'J':0, 'P':1}
b_Pers_list = [{0:'I', 1:'E'}, {0:'N', 1:'S'}, {0:'F', 1:'T'}, {0:'J', 1:'P'}]

def translate_personality(personality):
    # transform mbti to binary vector
    
    return [b_Pers[l] for l in personality]

# %%
# We want to remove these from the posts
unique_type_list = ['INFJ', 'ENTP', 'INTP', 'INTJ', 'ENTJ', 'ENFJ', 'INFP', 'ENFP',
       'ISFP', 'ISTP', 'ISFJ', 'ISTJ', 'ESTP', 'ESFP', 'ESTJ', 'ESFJ']
  
unique_type_list = [x.lower() for x in unique_type_list]


# Lemmatize
stemmer = PorterStemmer()
lemmatiser = WordNetLemmatizer()

# Cache the stop words for speed 
cachedStopWords = stopwords.words("english")

def pre_process_data(data, remove_stop_words=True, remove_mbti_profiles=True):

    list_personality = []
    list_posts = []
    len_data = len(data)
    i=0
    
    for row in data.iterrows():
        i+=1
        if (i % 500 == 0 or i == 1 or i == len_data):
            print("%s of %s rows" % (i, len_data))

        ##### Remove and clean comments using regular expressions
        posts = row[1].posts
        temp = re.sub('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', ' ', posts)
        temp = re.sub("[^a-zA-Z]", " ", temp)
        temp = re.sub(' +', ' ', temp).lower()
        if remove_stop_words:
            temp = " ".join([lemmatiser.lemmatize(w) for w in temp.split(' ') if w not in cachedStopWords])
        else:
            temp = " ".join([lemmatiser.lemmatize(w) for w in temp.split(' ')])
            
        if remove_mbti_profiles:
            for t in unique_type_list:
                temp = temp.replace(t,"")
        ##### Remove single-charactered words that remain from the cleaning
        words=temp.split()
        finalTemp=""
        for word in words:
            if(len(word)>1):
                finalTemp=finalTemp+" "+word
        type_labelized = translate_personality(row[1].type)
        list_personality.append(type_labelized)
        list_posts.append(finalTemp)

    list_posts = np.array(list_posts)
    list_personality = np.array(list_personality)
    return list_posts, list_personality

# %%
list_posts, list_personality  = pre_process_data(data, remove_stop_words=True)
# Out:
# 1 of 8675 rows
# 500 of 8675 rows
# 1000 of 8675 rows
# 1500 of 8675 rows
# 2000 of 8675 rows
# 2500 of 8675 rows
# 3000 of 8675 rows
# 3500 of 8675 rows
# 4000 of 8675 rows
# 4500 of 8675 rows
# 5000 of 8675 rows
# 5500 of 8675 rows
# 6000 of 8675 rows
# 6500 of 8675 rows
# 7000 of 8675 rows
# 7500 of 8675 rows
# 8000 of 8675 rows
# 8500 of 8675 rows
# 8675 of 8675 rows

# %%
print(list_posts[1])
print(list_personality[1])
print(data["labels"][1])
# Out:
#  finding lack post alarming sex boring position often example girlfriend currently environment creatively use cowgirl missionary enough giving new meaning game theory hello grin take converse flirting acknowledge presence return word smooth wordplay cheeky grin lack balance hand eye coordination real iq test score internet iq test funny score higher like former response thread mention believe iq test banish know vanish site year half return find people still commenting post liking idea thought know think thing sometimes go old sherlock holmes quote perhaps man special knowledge special power like rather encourages seek complex cheshirewolf tumblr com post really never thought real function judge use use ne ti dominates fe emotion rarely si also use ni due strength know though ingenious saying really want try see happens playing first person shooter back drive around want see look rock paper one best make lol guy lucky really high tumblr system hear new first person shooter game rocking hell soundtrack auto sound equipment shake heaven managed put couple way connected thing ne ne dominates aware environment se dominates example shawn spencer patrick jane well charlie first admit get jealous like chalk heart mixed dominate like noticed like known upload clip mic away mouth hear anything ninja assassin style splatter tik tok really great song long mental block singer love beat make bounce drop io swck mic really close mouth smokin ace assassin ball playing background sociable extrovert extrovert sociable sherlock movie normally played extj book said movie looked good except called sherlock holmes oh never fear kissing guy kiss animal nothing vanish personal taste liking guy kissed know one sound pretty much like area going right trying figure way want take life want many thing biggest problem know operating impression female never looked boxy okay help gay friend time one developed little crush get red described living worst nightmare trapped one place one one around dull wood serial killer would perfect place sadly tbh biased sound like shadowed think maybe hurt turned tell typical trait left check list sorry seems came bad time already reached quota however female like female make deal kick one antp leaning toward easy identify also imagine interrogation would go little bit like jack except mechanical rigging shock treatment equipment abandoned building old car batty jumper compliment trust psychopathic except emoticon weird one like laughing get hurt people running lawn mower like theme live know heart usual leave thing end mean time time work thing work mine mbp pleasure meet damn need trust instinct would closer going say exfp leaning toward way responded friend even gay lesbian one always come advice bow master great able build building duck duck duck shotgun never hard sad losing someone like knew right give big pat back awesome always correct oh tell stupid know play make laugh going take neuropsychology psychologist nightowl wake pm stay awake till personal opinion backed theory would suggest socially difficult socially indifferent also use social situation need arises personal stock desktop downloaded random stock site stock photobuckets tell open photoshop glad like static thanks made friend several hour work constructed every line static get avatar later one fellow teammate psychologist keep around long enough diagnosis like toy diagnosis psychologist friend friend tell
# [1 0 1 1]
# 6

# %%
#returns the max word numbers 
def max_post_words(posts):
    maxLen=0
    averageLen=0
    for post in posts:
        words=post.split()
        averageLen=averageLen+len(words)
        if maxLen < len(words):
            maxLen=len(words)
    averageLen=int(averageLen/len(posts))
    return maxLen,averageLen
print(list_posts.shape)
print(list_personality.shape)
maxlength,averagelen=max_post_words(list_posts)
print(maxlength)
print(averagelen)
# Out:
# (8675,)
# (8675, 4)
# 883
# 585

# %%
def read_glove_vecs(glove_file):
    with open(glove_file, 'r', encoding="utf8") as f:
        words = set()
        word_to_vec_map = {}
        for line in f:
            line = line.strip().split()
            curr_word = line[0]
            words.add(curr_word)
            word_to_vec_map[curr_word] = np.array(line[1:], dtype=np.float64)
        
        i = 1
        words_to_index = {}
        index_to_words = {}
        for w in sorted(words):
            words_to_index[w] = i
            index_to_words[i] = w
            i = i + 1
    return words_to_index, index_to_words, word_to_vec_map
word_to_index, index_to_word, word_to_vec_map = read_glove_vecs('./dataset/glove.6B/glove.6B.50d.txt')

# %%
print(word_to_index["finding"])
print(index_to_word[148433])
print(word_to_vec_map["finding"])
# Out:
# 148433
# finding
# [ 1.0427    -0.0063726  0.14249   -0.20253    0.81903    0.45835
#  -0.53618    0.4273     0.87353    0.36      -0.13102    0.031936
#  -0.3458     0.048457   0.53903    0.076773   0.51641   -0.39471
#   0.33282   -0.71322   -0.014848   0.5072     0.1407     0.052006
#   0.47805   -1.2841    -0.50835    0.040056   0.55624   -0.14598
#   2.6381    -0.19551   -0.22558   -1.0202     0.57369    0.20545
#  -0.14149    0.44701    0.17831   -0.55761   -0.14858   -0.14687
#   0.29202    0.35834    0.22295   -0.12368    0.12302    0.53954
#   0.29452   -0.051312 ]

# %%
def sentences_to_indices(X, word_to_index, max_len):
    m = X.shape[0]                                   
    X_indices = np.zeros((m,max_len))
    for i in range(m):
        if (i % 500 == 0 or i == 1 or i == m):
            print("%s of %s rows" % (i, m))
        sentence_words =X[i].lower().split()
        j = 0
        for w in sentence_words:
            if j==max_len:
                break
            if w in word_to_index:
                X_indices[i, j] = word_to_index[w]
            j = j+1
    return X_indices
X=sentences_to_indices(list_posts, word_to_index, averagelen)
print(X.shape)
# Out:
# 0 of 8675 rows
# 1 of 8675 rows
# 500 of 8675 rows
# 1000 of 8675 rows
# 1500 of 8675 rows
# 2000 of 8675 rows
# 2500 of 8675 rows
# 3000 of 8675 rows
# 3500 of 8675 rows
# 4000 of 8675 rows
# 4500 of 8675 rows
# 5000 of 8675 rows
# 5500 of 8675 rows
# 6000 of 8675 rows
# 6500 of 8675 rows
# 7000 of 8675 rows
# 7500 of 8675 rows
# 8000 of 8675 rows
# 8500 of 8675 rows
# (8675, 585)

# %%
# Add Features to Inputs
'''X=np.ndarray.tolist(X)
waste=[post.append(data['words_per_comment'][i]) for i,post in enumerate(X)]
waste=[post.append(data['question_per_comment'][i]) for i,post in enumerate(X)]
waste=[post.append(data['excl_per_comment'][i]) for i,post in enumerate(X)]
waste=[post.append(data['ellipsis_per_comment'][i]) for i,post in enumerate(X)]
#waste=[post.append(data['@_per_comment'][i]) for i,post in enumerate(X)]
#waste=[post.append(data['#_per_comment'][i]) for i,post in enumerate(X)]
waste=[post.append(data['emojis_per_comment'][i]) for i,post in enumerate(X)]
print(X[0])
X=np.array(X)
print(X[0])'''
# Out:
# "X=np.ndarray.tolist(X)\nwaste=[post.append(data['words_per_comment'][i]) for i,post in enumerate(X)]\nwaste=[post.append(data['question_per_comment'][i]) for i,post in enumerate(X)]\nwaste=[post.append(data['excl_per_comment'][i]) for i,post in enumerate(X)]\nwaste=[post.append(data['ellipsis_per_comment'][i]) for i,post in enumerate(X)]\n#waste=[post.append(data['@_per_comment'][i]) for i,post in enumerate(X)]\n#waste=[post.append(data['#_per_comment'][i]) for i,post in enumerate(X)]\nwaste=[post.append(data['emojis_per_comment'][i]) for i,post in enumerate(X)]\nprint(X[0])\nX=np.array(X)\nprint(X[0])"

# %%
def pretrained_embedding_layer(word_to_vec_map, word_to_index):
    vocab_len = len(word_to_index) + 1
    emb_dim = word_to_vec_map["cucumber"].shape[0] 
    
    emb_matrix = np.zeros((vocab_len,emb_dim))
    for word, idx in word_to_index.items():
        emb_matrix[idx, :] = word_to_vec_map[word]
    embedding_layer = Embedding(vocab_len,emb_dim) 
    embedding_layer.build((None,)) 
    embedding_layer.set_weights([emb_matrix])
    
    return embedding_layer

# %%
def multi_loss(y_true,y_pred):
    return K.exp(K.mean(K.log(K.mean(K.square(y_pred - y_true), axis=0)), axis=-1))
def multi_loss2(y_true,y_pred):
    return K.mean(K.sum(K.binary_crossentropy(y_true,y_pred)))

# %%
def f1(y_true, y_pred):
    def recall(y_true, y_pred):
        """Recall metric.

        Only computes a batch-wise average of recall.

        Computes the recall, a metric for multi-label classification of
        how many relevant items are selected.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision(y_true, y_pred):
        """Precision metric.

        Only computes a batch-wise average of precision.

        Computes the precision, a metric for multi-label classification of
        how many selected items are relevant.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
def personnality_model(input_shape, word_to_vec_map, word_to_index):
    
    sentence_indices = Input(shape=input_shape, dtype='int32')
    embedding_layer = pretrained_embedding_layer(word_to_vec_map, word_to_index)
    embeddings = embedding_layer(sentence_indices)   
    X = Bidirectional(LSTM(128,return_sequences=False))(embeddings)
    X = Dropout(0.25)(X)
    ''' X = Dense(1)(X)
    X = Activation('sigmoid')(X)
    '''
    X1=Dense(1,name="I/E_classifier")(X)
    X1Output=Activation("sigmoid")(X1)
    '''
    X2=Dense(1,name="N/S_classifier")(X)
    X2Output=Activation("sigmoid")(X2)
    
    X3=Dense(1,name="F/T_classifier")(X)
    X3Output=Activation("sigmoid")(X3)
    
    X4=Dense(1,name="J/P_classifier")(X)
    X4Output=Activation("sigmoid")(X4)'''
    model = model = Model(inputs=sentence_indices, outputs=X1Output)
    return model

task_list=['I/E_classifier','N/S_classifier','F/T_classifier','J/P_classifier']
model = personnality_model((averagelen,), word_to_vec_map, word_to_index)
model.summary()
# Out:
#   File "<ipython-input-22-4eb873842b82>", line 27
#     model.summary()
#
# ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
Y = list_personality

# %%
# initializing some hyperparameters
INIT_LR = 0.001
EPOCHS = 10
BS = 32
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)
model.compile(loss=multi_loss2, optimizer=opt, metrics=['accuracy',f1])
(X_train, X_temp, Y_train, Y_temp) = train_test_split(X,Y,test_size=0.2, random_state=42)
(X_valid, X_test, Y_valid, Y_test) = train_test_split(X_temp,Y_temp,test_size=0.5, random_state=42)
history=model.fit(X_train, Y_train,validation_data=(X_valid,Y_valid), batch_size=BS , epochs = EPOCHS, shuffle=True)
# Out:
# Train on 6940 samples, validate on 867 samples
# Epoch 1/10
# 6940/6940 [==============================] - 169s 24ms/step - loss: 74.0677 - accuracy: 0.2339 - f1: 0.5368 - val_loss: 73.5051 - val_accuracy: 0.2249 - val_f1: 0.5238
# Epoch 2/10
# 6940/6940 [==============================] - 171s 25ms/step - loss: 72.1006 - accuracy: 0.2680 - f1: 0.5795 - val_loss: 71.0140 - val_accuracy: 0.3310 - val_f1: 0.6153
# Epoch 3/10
# 6940/6940 [==============================] - 172s 25ms/step - loss: 69.3824 - accuracy: 0.3225 - f1: 0.6130 - val_loss: 70.3369 - val_accuracy: 0.3230 - val_f1: 0.6025
# Epoch 4/10
# 6940/6940 [==============================] - 171s 25ms/step - loss: 66.5794 - accuracy: 0.3441 - f1: 0.6295 - val_loss: 71.9383 - val_accuracy: 0.2722 - val_f1: 0.5516
# Epoch 5/10
# 6940/6940 [==============================] - 170s 24ms/step - loss: 62.5790 - accuracy: 0.3654 - f1: 0.6497 - val_loss: 73.1738 - val_accuracy: 0.3518 - val_f1: 0.6341
# Epoch 6/10
# 6940/6940 [==============================] - 170s 24ms/step - loss: 55.9849 - accuracy: 0.4032 - f1: 0.6977 - val_loss: 77.5119 - val_accuracy: 0.2664 - val_f1: 0.6089
# Epoch 7/10
# 6940/6940 [==============================] - 170s 24ms/step - loss: 50.0163 - accuracy: 0.4278 - f1: 0.7338 - val_loss: 81.9772 - val_accuracy: 0.3552 - val_f1: 0.5111
# Epoch 8/10
# 6940/6940 [==============================] - 170s 25ms/step - loss: 40.7406 - accuracy: 0.4699 - f1: 0.7976 - val_loss: 89.3514 - val_accuracy: 0.3518 - val_f1: 0.5415
# Epoch 9/10
# 6940/6940 [==============================] - 170s 24ms/step - loss: 32.0742 - accuracy: 0.5037 - f1: 0.8530 - val_loss: 97.2822 - val_accuracy: 0.3541 - val_f1: 0.5516
# Epoch 10/10
# 6940/6940 [==============================] - 170s 24ms/step - loss: 24.0357 - accuracy: 0.5293 - f1: 0.8950 - val_loss: 114.4090 - val_accuracy: 0.3230 - val_f1: 0.5621

# %%
test_loss, test_acc,test_f1 = model.evaluate(X_train,Y_train)
print("Accuracy : ",test_acc)
print("F1 Score :",test_f1)
print("Loss :",test_loss)
Yhat=model.predict(X_train)
correct=0
correctlabels=[0,0,0,0]
for i,prediction in enumerate(Yhat):
    for j,value in enumerate(prediction):
        if (value<0.5):
            prediction[j]=0
        else:
            prediction[j]=1
        if(prediction[j]==Y_train[i][j]):
            correctlabels[j]+=1
    if (np.array_equal(prediction,Y_train[i])):
        correct+=1
    print("Prediction :",prediction," Actual Value :",Y_train[i] )
print("Total accuracy : ",correct/len(X_test))
print("I/E accuracy : ",correctlabels[0]/len(X_train))
print("N/S accuracy : ",correctlabels[1]/len(X_train))
print("F/T accuracy : ",correctlabels[2]/len(X_train))
print("J/P accuracy : ",correctlabels[3]/len(X_train))
print("Binary accuracy :",np.sum(correctlabels)/(4*len(X_train)))
# Out:
# 6940/6940 [==============================] - 26s 4ms/step
# Accuracy :  0.5151296854019165
# F1 Score : 0.9308570027351379
# Loss : 17.082179352598164
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 0. 0.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 1. 0. 0.]  Actual Value : [1 1 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [1. 0. 1. 0.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 1 0 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 1 1 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [1. 0. 0. 0.]  Actual Value : [1 0 0 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 1 1 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [1. 0. 0. 0.]  Actual Value : [1 0 0 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 0.]  Actual Value : [1 0 0 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 1. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 1. 0. 0.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 0. 0.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 1. 1. 0.]  Actual Value : [1 1 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [1 1 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 1. 0. 0.]  Actual Value : [0 1 0 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 1. 0.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [1. 1. 1. 1.]  Actual Value : [1 1 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 1. 1.]  Actual Value : [1 1 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 1. 0.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 1. 0.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 1. 1. 1.]  Actual Value : [1 1 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 1. 0. 0.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 1 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [1. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 0.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 1 1 0]
# Prediction : [1. 1. 1. 1.]  Actual Value : [1 1 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 0. 0.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 1. 0.]  Actual Value : [1 1 1 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 1. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 1. 1. 0.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 1. 1. 0.]  Actual Value : [1 1 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [1. 1. 0. 0.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [1. 0. 0. 0.]  Actual Value : [1 0 0 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 1. 0.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 1. 0. 0.]  Actual Value : [0 1 0 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 1. 0. 1.]  Actual Value : [1 1 0 0]
# Prediction : [1. 1. 1. 0.]  Actual Value : [1 1 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 1 1 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 1. 0.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 1. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 1. 0. 1.]  Actual Value : [1 1 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 1. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [1. 0. 0. 0.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 1. 0. 0.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 1. 1. 1.]  Actual Value : [1 1 1 1]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 0. 0.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 0. 0.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 1. 1. 1.]  Actual Value : [1 1 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 1 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 0 0]
# Prediction : [1. 1. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 1. 0. 0.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [1. 1. 1. 1.]  Actual Value : [1 1 1 0]
# Prediction : [1. 0. 1. 0.]  Actual Value : [1 0 1 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 1 1 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 1 0 0]
# Prediction : [1. 1. 1. 1.]  Actual Value : [1 1 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 1 0 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [1. 1. 0. 0.]  Actual Value : [1 1 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 1. 1. 1.]  Actual Value : [1 1 1 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 1. 1. 0.]  Actual Value : [1 1 1 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 1. 0. 0.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 1. 1. 0.]  Actual Value : [1 1 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 0. 0.]  Actual Value : [1 0 0 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 0]
# ...
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 1. 1. 1.]  Actual Value : [1 1 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 0.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 1 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 1 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 1. 0. 0.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 1 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 1. 0. 0.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 1. 0. 1.]  Actual Value : [1 1 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [1. 1. 0. 1.]  Actual Value : [1 1 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 1. 1. 1.]  Actual Value : [1 1 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 1. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 1. 0. 0.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 1. 0. 0.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 0 0]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [1. 1. 1. 1.]  Actual Value : [1 1 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 1 0 1]
# Prediction : [1. 1. 1. 1.]  Actual Value : [1 1 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 1 0 1]
# Prediction : [1. 0. 1. 0.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 0. 0.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Total accuracy :  6.6658986175115205
# I/E accuracy :  0.926657060518732
# N/S accuracy :  0.9495677233429395
# F/T accuracy :  0.9884726224783862
# J/P accuracy :  0.943371757925072
# Binary accuracy : 0.9520172910662824

# %%
test_loss, test_acc,test_f1 = model.evaluate(X_test,Y_test)
print("Accuracy : ",test_acc)
print("F1 Score :",test_f1)
print("Loss :",test_loss)
Yhat=model.predict(X_test)
correct=0
correctlabels=[0,0,0,0]
for i,prediction in enumerate(Yhat):
    for j,value in enumerate(prediction):
        if (value<0.5):
            prediction[j]=0
        else:
            prediction[j]=1
        if(prediction[j]==Y_test[i][j]):
            correctlabels[j]+=1
    if (np.array_equal(prediction,Y_test[i])):
        correct+=1
    print("Prediction :",prediction," Actual Value :",Y_test[i] )
print("Total accuracy : ",correct/len(X_test))
print("I/E accuracy : ",correctlabels[0]/len(X_test))
print("N/S accuracy : ",correctlabels[1]/len(X_test))
print("F/T accuracy : ",correctlabels[2]/len(X_test))
print("J/P accuracy : ",correctlabels[3]/len(X_test))
print("Binary accuracy :",np.sum(correctlabels)/(4*len(X_test)))
# Out:
# 868/868 [==============================] - 3s 4ms/step
# Accuracy :  0.32603687047958374
# F1 Score : 0.5362933874130249
# Loss : 114.67654062086537
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 0. 0.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 1 1 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 1 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 0.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 0. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 1. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 1. 0. 0.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 1 1 1]
# Prediction : [1. 1. 1. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 1 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 1. 0.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 0. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 0]
# Prediction : [1. 1. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 1 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 1. 1. 0.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 1 1 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 0 1]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 1 0 1]
# Prediction : [0. 1. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 1 0 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 1 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 1]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 1 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 0 1]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 1 1 1]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 1 0 1]
# Prediction : [0. 1. 0. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 1 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [1. 0. 0. 0.]  Actual Value : [1 1 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 1 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 1 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 1 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 1 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 1. 1. 1.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 1]
# Prediction : [0. 1. 1. 0.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 1 0 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 1. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 1 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 1 1 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 0 0]
# Prediction : [1. 0. 0. 0.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 1 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [1. 1. 1. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 1 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 0. 0.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [1. 1. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [1. 1. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 1. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 1 0]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 0]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 1 1 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 1 0 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 0]
# Prediction : [1. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [1. 1. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 1. 0. 0.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 1. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 1 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 1. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 1 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 1. 0. 0.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 1 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 1 0 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 1 0 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 1 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 1 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 1. 1. 1.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 1 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 0]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [1 0 1 1]
# Prediction : [0. 0. 1. 0.]  Actual Value : [0 0 1 1]
# Prediction : [0. 0. 0. 0.]  Actual Value : [0 0 0 1]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 0 1]
# Prediction : [0. 1. 1. 0.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 0. 1.]  Actual Value : [0 0 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 0. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 1.]  Actual Value : [0 0 0 0]
# Prediction : [0. 0. 1. 0.]  Actual Value : [1 0 1 1]
# Prediction : [1. 0. 1. 1.]  Actual Value : [0 0 1 0]
# Prediction : [1. 0. 1. 1.]  Actual Value : [1 0 1 0]
# Total accuracy :  0.2108294930875576
# I/E accuracy :  0.706221198156682
# N/S accuracy :  0.8202764976958525
# F/T accuracy :  0.6981566820276498
# J/P accuracy :  0.5195852534562212
# Binary accuracy : 0.6860599078341014

# %%
# plotting Accuracy
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# %%
# plotting Losshistory
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='lower right')
